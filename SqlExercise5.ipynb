# %% [markdown]
# <a href="https://colab.research.google.com/github/amit-eyal/campus_il_sql_course/blob/main/SqlExercise5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div dir=rtl align=center>
#
# # <div dir="rtl"><font color='BLUE'><b>התנסו בכתיבת שאילתות SQL מתקדמות
# </b></font>
# </div>

# %% [markdown]
# <div dir="rtl" align="center">
# <b><font color="Grey">
# <font color='#141C3A'>
#  כתיבת פקודות SQL:
# </div>

# %% [markdown]
# <div dir="rtl">
# <font color="Grey">
# מומלץ לשמור עותק של סביבת הקולאב במחשב שלכם, מכיוון שהזיכרון של הקונסולה האינטראקטיבית מתאפס כשמרעננים את עמוד האינטרנט בדפדפן.
# <br>
# בהצלחה!
# </font>
# </div>
# <hr>

# %% [markdown]
# <div dir=rtl align=right>
#
# ## <div dir="rtl"><font color='BLUE'><b>חשוב להדגיש</b></font></div>
#
# בעולם האמיתי, מידע של ארגונים מאוחסן במערכות RDBMS המוקמות על שרת מרוחק,
# ועל מנת להריץ שאילתות SQL נצטרך להתחבר אל המערכת היושבת בשרת המרוחק.
# למטרות למידה ותרגול, נשתמש בפתרון קל יותר, בעזרת ספריית SQLite נוכל להקים מסד נתונים מקומי בצורה מהירה ונוחה,
# ולהריץ שאילתות SQL עליו באופן שדומה לעבודה עם מערכת RDBMS מלאה.
#
# קיימות שיטות שונות להרצת שאילתות SQL בסביבת Google Colab (פלטפורמה מקוונת של גוגל לכתיבה והרצה של קוד בצורה אינטראקטיבית).
# אנחנו נבחר להשתמש בספרייה בשם ipython-sql.
# Ipython-sql הוא הרחבה ל-IPython, הוא מספק סביבת עבודה המאפשרת להריץ שאילתות SQL ישירות מתוך הסביבה (ללא שימוש בAPI שעוטף את הבקשות).
# לאחר שטוענים את התוסף באמצעות הפקודה ```load_ext sql%```, ניתן להריץ שאילתות SQL ישירות מתוך סביבת העבודה.
#
# 2 יתרונות נוספים לשימוש בתוסף, התוסף מאפשר הדגשת תחביר והשלמת קוד SQL באופן אוטומטי.
# דבר שהופך את חווית הכתיבה לנוחה וידידותית יותר.
#
# </div>

# %% [markdown]
# <div dir=rtl align=right>
#
# ## <div dir="rtl"><font color='BLUE'><b>לפני הרצת שאילתות</b></font></div>
#
#
# פשוט הריצו את הקטע הבא:
# הכולל את התקנת הספרייה וטעינת התוסף sql
# </div>

# %% [markdown]
# ## Connetion

# %%
# !pip install sqlalchemy>=2.0
# !pip install ipython-sql
# load sql extention in order to use it above.
# %load_ext sql
# change the design of the table result
# %config SqlMagic.autopandas = True
# Out:
# Requirement already satisfied: ipython-sql in /usr/local/lib/python3.12/dist-packages (0.5.0)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.12/dist-packages (from ipython-sql) (3.17.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from ipython-sql) (7.34.0)
# Requirement already satisfied: sqlalchemy>=2.0 in /usr/local/lib/python3.12/dist-packages (from ipython-sql) (2.0.48)
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.12/dist-packages (from ipython-sql) (0.5.5)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from ipython-sql) (1.17.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.12/dist-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=2.0->ipython-sql) (3.3.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=2.0->ipython-sql) (4.15.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (75.2.0)
# Collecting jedi>=0.16 (from ipython->ipython-sql)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (4.9.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prettytable->ipython-sql) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.4 MB/s eta 0:00:00
# Installing collected packages: jedi
# Successfully installed jedi-0.19.2

# %% [markdown]
# <div dir=rtl align=right>
#
# ## <div dir="rtl"><font color='BLUE'><b>טעינת הדאטה</b></font></div>
#
# </div>

# %% [markdown]
# <div dir=rtl align=right>
#
# הריצו את הפקודה הבאה:
#
# ``` "wget -O employees.sqlite3 "https://drive.google.com/uc?export=download&id=1ThJIPMRMlXOedWG2JIse0fod1wxc6XGu! ```
#
# הפקודה תבצע הורדה של קובץ ה-DB של employees.sqlite3 ישירות ל-files שלכם.

# %% [markdown]
# <div dir=rtl align=center>
#
# ![image.png](data:image/png;base64,...)
# </div>

# %%
# !wget -O employees.sqlite3 "https://drive.google.com/uc?export=download&id=1ThJIPMRMlXOedWG2JIse0fod1wxc6XGu"
# Out:
# --2026-03-17 12:24:52--  https://drive.google.com/uc?export=download&id=1ThJIPMRMlXOedWG2JIse0fod1wxc6XGu
# Resolving drive.google.com (drive.google.com)... 142.250.98.139, 142.250.98.100, 142.250.98.138, ...
# Connecting to drive.google.com (drive.google.com)|142.250.98.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1ThJIPMRMlXOedWG2JIse0fod1wxc6XGu&export=download [following]
# --2026-03-17 12:24:52--  https://drive.usercontent.google.com/download?id=1ThJIPMRMlXOedWG2JIse0fod1wxc6XGu&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.107.132, 2607:f8b0:400c:c32::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.107.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2097152 (2.0M) [application/octet-stream]
# Saving to: ‘employees.sqlite3’
#
# employees.sqlite3   100%[===================>]   2.00M  --.-KB/s    in 0.03s
#
# 2026-03-17 12:24:53 (66.5 MB/s) - ‘employees.sqlite3’ saved [2097152/2097152]

# %% [markdown]
# <div dir=rtl align=right>
#
#  ולבסוף הריצו את הפקודה הבאה:
#
# `sql sqlite:///employees.sqlite3 %`
#
#
# לאחר הרצת הפקודה נוצר חיבור לקובץ מסד הנתונים employees.sqlite3 של SQLite.
#
# </div>

# %%
# %sql sqlite:///employees.sqlite3
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'
# Out:
# UsageError: Line magic function `%sql` not found.

# %% [markdown]
# <div dir=rtl align=right>
#
# סיימנו את שלב טעינת הנתונים למאגר!
# כעת כל שאילתה שנעשה תרוץ מול הדאטה בייס (DB) של העובדים - employees.sqlite3 שהגדרנו!

# %% [markdown]
# <div dir="rtl">
#
# ## <div dir="rtl"><font color='BLUE'><b>דוגמא</b></font></div>
#
#  שאילתה שמחזירה את כל המידע מטבלת employees

# %%
# %%sql
# SELECT *
# FROM employees
# Out:
#  * sqlite:///employees.sqlite3
# Done.
#       emp_no  birth_date first_name  last_name gender   hire_date
# 0      10184  1957-05-22    Mihalis     Lowrie      M  1987-10-29
# 1      10264  1958-09-08     Nalini  Kawashimo      F  1997-07-16
# 2      10328  1955-06-28  Serenella  Kawashima      M  1994-01-16
# 3      10605  1956-05-21       Moti      Wixon      F  1985-04-29
# 4      10735  1964-09-12     Morrie     Gewali      M  1985-10-29
# ...      ...         ...        ...        ...    ...         ...
# 2432  499593  1964-01-31     Mantis  Kawashima      F  1990-07-16
# 2433  499668  1956-11-29      Kokou     Gewali      M  1991-06-12
# 2434  499695  1953-03-26   Srinidhi  Kawashimo      F  1989-06-07
# 2435  499731  1953-02-03  Yechezkel       Pews      F  1992-10-23
# 2436  499902  1952-07-31      Aloke   Wuwongse      F  1991-06-18
#
# [2437 rows x 6 columns]

# %% [markdown]
# <div dir="rtl">
#
# ## <div dir="rtl"><font color='BLUE'><b>שאלה 1 -</b></font></div>
#
# מבלי להשתמש בשאילתות מקוננות, הפיקו טבלה המציגה את שמות המשפחה הנפוצים - כך שיש למעלה מ-200 עובדים לכל אחד משמות המשפחה האלו. (שם המשפחה נתון בעמודה last_name של טבלת העובדים employees).

# %%
# %%sql
# #  .. כתוב/י כאן את השאילתה
# Out:
#  * sqlite:///employees.sqlite3
# (sqlite3.OperationalError) unrecognized token: "#"
# [SQL: #  .. כתוב/י כאן את השאילתה]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# <div dir="rtl">
#
# ## <div dir="rtl"><font color='BLUE'><b>שאלה 2 -</b></font></div>
#
# באמצעות מילת המפתח IN ושאילתה מקוננת, הציגו את המשכורות השונות של עובדים שהועסקו לאחר התאריך '1999-08-20' (לא כולל).

# %%
# %%sql
# #  .. כתוב/י כאן את השאילתה
# Out:
#  * sqlite:///employees.sqlite3
# (sqlite3.OperationalError) unrecognized token: "#"
# [SQL: #  .. כתוב/י כאן את השאילתה]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# <div dir="rtl">
#
# ## <div dir="rtl"><font color='BLUE'><b>שאלה 3 -</b></font></div>
#
# הציגו רק את חמשת העובדים הוותיקים ביותר(מבחינת וותק שנות עבודה), כך שיוצגו עבורם כל העמודות של טבלת העובדים (employees) בדיוק כפי שהן במקור.

# %%
# %%sql
# #  .. כתוב/י כאן את השאילתה
# Out:
#  * sqlite:///employees.sqlite3
# (sqlite3.OperationalError) unrecognized token: "#"
# [SQL: #  .. כתוב/י כאן את השאילתה]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# <div dir="rtl">
#
# ## <div dir="rtl"><font color='BLUE'><b>שאלה 4 -</b></font></div>
#
# הציגו את העובדים שהאות השנייה בשם המשפחה שלהם היא "s", כך שיוצגו עבורם כל העמודות של טבלת העובדים (employees) בדיוק כפי שהן במקור. השתמשו במילת המפתח LIKE.

# %%
# %%sql
# #  .. כתוב/י כאן את השאילתה
# Out:
#  * sqlite:///employees.sqlite3
# (sqlite3.OperationalError) unrecognized token: "#"
# [SQL: #  .. כתוב/י כאן את השאילתה]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
